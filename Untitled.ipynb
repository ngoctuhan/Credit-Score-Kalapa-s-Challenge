# %%
import pandas as pd 
import numpy as np 
import os

# %%
# read file train
train_file = 'train.csv'
test_file = 'test.csv'

df_train = pd.read_csv(train_file, encoding='utf-8')
df_test = pd.read_csv(train_file, encoding='utf-8')
df_train.head()
# Out:
#    id  label               province               district  age_source1  \
# 0   0      0                    NaN                    NaN          NaN
# 1   1      0          Tỉnh Đồng Nai     Thành phố Biên Hòa         44.0
# 2   2      0          Tỉnh Đồng Nai       Huyện Long Thành         30.0
# 3   3      0       Tỉnh Tuyên Quang  Thành phố Tuyên Quang         43.0
# 4   4      0  Thành phố Hồ Chí Minh                 Quận 1         21.0
#
#    age_source2       maCv  FIELD_1  FIELD_2  FIELD_3  ...  FIELD_48  FIELD_49  \
# 0          NaN        NaN        1      1.0   2547.0  ...      True      True
# 1         44.0       None        1      0.0     -1.0  ...     False      True
# 2         30.0  Công nhân        0      1.0   3273.0  ...      True      True
# 3          NaN        NaN        0      1.0   3991.0  ...      True     False
# 4         21.0       None        0      1.0   1450.0  ...      True      True
#
# ...

# %%
def process_data(df):
    '''
    Input : data frame loaded from a file csv include: field, etc...
    Main process: 
     + Drop rows
     + TF-IDF data: FIELD
     + NLP data Text: provice, district 
     + Add value for none line
    Output: id: array, label : array, feature vector: array
    '''
    id = df['id'].values
    label = df['label'].values
    
    
    
    
    return id, label
    
#     return id, label, feature_vector
    
process_data(df_train)
# Out:
# [    0     1     2 ... 29997 29998 29999]
